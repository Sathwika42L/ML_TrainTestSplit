# %%
import pandas as pd
df=pd.read_csv("train_test_model.csv")
df.head()
# Out:
#    Milleage  Age(yrs)  SellPrice($)
# 0     69000         6         18000
# 1     35000         3         34000
# 2     57000         5         26100
# 3     22500         2         40000
# 4     46000         4         31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Milleage'],df['SellPrice($)'])

# %%
plt.scatter(df['Age(yrs)'],df['SellPrice($)'])

# %%
x=df[['Milleage','Age(yrs)']]

# %%
y=df['SellPrice($)']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#    Milleage  Age(yrs)
# 0     69000         6
# 2     57000         5
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 4     46000         4
# 8     91000         8

# %%
x_test
# Out:
#    Milleage  Age(yrs)
# 9     67000         6
# 1     35000         3
# 7     72000         6

# %%
y_train
# Out:
# 0    18000
# 2    26100
# 5    26750
# 6    32000
# 3    40000
# 4    31500
# 8    12000
# Name: SellPrice($), dtype: int64

# %%
y_test
# Out:
# 9    22000
# 1    34000
# 7    19300
# Name: SellPrice($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([22805.52898056, 35174.18463068, 17846.53040939])

# %%
y_test
# Out:
# 9    22000
# 1    34000
# 7    19300
# Name: SellPrice($), dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.966191733331286

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
x_test
# Out:
#    Milleage  Age(yrs)
# 8     91000         8
# 2     57000         5
# 5     59000         5
